# %%
import torch

scalar = torch.tensor(10)
vector = torch.tensor([1,2,3,4])
matrix = torch.tensor([
  [1,2],
  [3,4],
  [5,6]
])

print(scalar)
print(vector)
print(matrix)

print(scalar.shape)
print(vector.shape)
print(matrix.shape)
# Out:
# tensor(10)
# tensor([1, 2, 3, 4])
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# torch.Size([])
# torch.Size([4])
# torch.Size([3, 2])
